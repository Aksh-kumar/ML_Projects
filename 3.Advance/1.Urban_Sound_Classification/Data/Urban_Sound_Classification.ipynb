# %%
import os
import pandas as pd
import librosa
import glob 
import IPython.display as ipd
import matplotlib.pyplot as plt
import librosa.display

# %%
folder_path_train = 'C://Users//aksh1//Documents//Songs_data//1.Urban_Sound_Classification//Data//train//'
folder_path_train = 'C:/Users/aksh1/Documents/Songs_data/1.Urban_Sound_Classification/Data/test/'
train_path = folder_path_train + 'Train//'
path = os.path.join(train_path + '2022.wav')
ipd.Audio(path)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-4ff3c6347df3> in <module>()
#       3 train_path = folder_path_train + 'Train//'
#       4 path = os.path.join(train_path + '2022.wav')
# ----> 5 ipd.Audio(path)
#
# C:\Anaconda\lib\site-packages\IPython\lib\display.py in __init__(self, data, filename, url, embed, rate, autoplay)
#      98
#      99         if self.data is not None and not isinstance(self.data, bytes):
# --> 100             self.data = self._make_wav(data,rate)
#     101
#     102     def reload(self):
#
# C:\Anaconda\lib\site-packages\IPython\lib\display.py in _make_wav(self, data, rate)
#     122             import numpy as np
#     123
# --> 124             data = np.array(data, dtype=float)
#     125             if len(data.shape) == 1:
#     126                 nchan = 1
#
# ...

# %%
data, sampling_rate = librosa.load(path + '2022.wav')

# %%
plt.figure(figsize=(12, 4))
librosa.display.waveplot(data, sr=sampling_rate)

# %%
train = pd.read_csv('./train/train.csv')

# %%
import random
i = random.choice(train.index)

# %%
audio_name = train.ID[i]

# %%
file_path = path + str(audio_name) + '.wav'
